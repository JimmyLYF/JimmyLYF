# %%
pip install fuzzywuzzy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: fuzzywuzzy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dab056ce-bd65-4355-a020-d572367442fc/lib/python3.8/site-packages (0.18.0)
# Python interpreter will be restarted.
# </div>

# %%
pip install openpyxl
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: openpyxl in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dab056ce-bd65-4355-a020-d572367442fc/lib/python3.8/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dab056ce-bd65-4355-a020-d572367442fc/lib/python3.8/site-packages (from openpyxl) (1.1.0)
# Python interpreter will be restarted.
# </div>

# %%
import pandas as pd
import numpy as np
import re
import string

import pickle
import matplotlib.pyplot as plt
import nltk
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem  import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy import spatial
from fuzzywuzzy import fuzz

from datetime import datetime
from decimal import Decimal
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-dab056ce-bd65-4355-a020-d572367442fc/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn(&#39;Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning&#39;)
# </div>

# %%
###Load STG1 & STG2 Model Result
stg1_model_src = '/dbfs/FileStore/shared_uploads/xiaomeng.fan@aia.com/POS_MAIA_Questions_Classification_Model.sav'
stg2_model_src = '/dbfs/FileStore/shared_uploads/xiaomeng.fan@aia.com/POS_MAIA_Answer_Examination_Model.sav'

stg1_model = pickle.load(open(stg1_model_src,'rb'))
stg2_model = pickle.load(open(stg2_model_src,'rb'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
### Query Last Month Data
query_batch_raw = spark.sql("""
select distinct question, prediction as response, probability as confidence from hive_metastore.ops_aos_read.maia_training
where
month(current_date())-month(createdDate) = 1
and length(user_id) = 5
and appSource = 'AGIA'
and role in ('AGY', 'AFA')
-- filter not null responses
and probability is not null
""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_batch_raw = query_batch_raw.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [confidence] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# </div>

# %%
### Load MAIA Stopwords + NLTK Stopwords
stopwords_query_result = spark.sql("""
select * from ops_pos_wrk.aosda_maia_stopwords
""")

df_stopwords = stopwords_query_result.toPandas()
maia_sw_list = df_stopwords['stopword'].tolist()

stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.extend(maia_sw_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Stage 1

# %%
### Stg1 Data Pre-processing
## Load POS Unique Term
file_path = "/dbfs/FileStore/shared_uploads/xiaomeng.fan@aia.com/"
df_pos_term = pd.read_excel(file_path+"pos_terms.xlsx")
pos_term_list = "|".join([i.lower() for i in df_pos_term['pos_terms']])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def qns_preprocessing(text):
  lemmatizer = WordNetLemmatizer()
  pol_format = re.compile(r'\w{1}\d{9}')
  nric_format = re.compile(r'[sfgtm]\d{7}[a-z]')
  emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
  
  text_orig = text.lower()
  text_pol_clean = pol_format.sub('AIAPolNum',text_orig)
  text_pol_nric_clean = nric_format.sub('CustNRIC',text_pol_clean)
  text_pol_nric_posterm_clean = re.sub(pos_term_list, 'AIAPOSTerm', text_pol_nric_clean)
  text_pol_nric_posterm_dpmt_clean = re.sub(r'cnc|pos|u&i|clm','OpsDpmt', text_pol_nric_posterm_clean)
  text_pol_nric_posterm_dpmt_sw_clean = " ".join([word for word in nltk.word_tokenize(text_pol_nric_posterm_dpmt_clean) if word not in stopword_list])
  text_pol_nric_posterm_dpmt_sw_punc_clean = " ".join(word.strip(string.punctuation) for word in text_pol_nric_posterm_dpmt_sw_clean.split())
  text_pol_nric_posterm_dpmt_sw_punc_lem_clean = " ".join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(text_pol_nric_posterm_dpmt_sw_punc_clean)]) ## 1. why some have [] some dont  2. why token not split()
  
  return text_pol_nric_posterm_dpmt_sw_punc_lem_clean

df_batch_raw['qns_clean'] = df_batch_raw['question'].apply(qns_preprocessing)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
###Load the Stg1 original cleaned data
df_stg1_training = pd.read_pickle(file_path+"stg1_clean.pkl")
display(df_stg1_training)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>qns</th><th>tag</th><th>qns_clean</th></tr></thead><tbody><tr><td>H223497209 giro</td><td>CNC</td><td>AIAPolNum giro</td></tr><tr><td>Thanks thats all</td><td>Small Talk</td><td>thats</td></tr><tr><td>Q514050177</td><td>Small Talk</td><td>AIAPolNum</td></tr><tr><td>Q514050177 dividend</td><td>POS</td><td>AIAPolNum dividend</td></tr><tr><td>Q514050177 dividend payment</td><td>POS</td><td>AIAPolNum dividend payment</td></tr><tr><td>L533278532 coupon</td><td>POS</td><td>AIAPolNum coupon</td></tr><tr><td>Q514050177 dividend withdrawal</td><td>POS</td><td>AIAPolNum dividend withdrawal</td></tr><tr><td>premium holiday</td><td>POS</td><td>premium holiday</td></tr><tr><td>replacement</td><td>Small Talk</td><td>replacement</td></tr><tr><td>yes</td><td>Small Talk</td><td></td></tr><tr><td>P564500596</td><td>Small Talk</td><td>AIAPolNum</td></tr><tr><td>A510008660 - client feedback not yet got her monthly payout, please check</td><td>CNC</td><td>AIAPolNum feedback got monthly payout</td></tr><tr><td>H235938743 reinstatement</td><td>POS</td><td>AIAPolNum reinstatement</td></tr><tr><td>Stay safe and bye</td><td>Small Talk</td><td>stay safe</td></tr><tr><td>H224151117 - client signed and sent in a counteroffer, why counter offer closed?</td><td>POS</td><td>AIAPolNum signed sent counteroffer counter offer closed</td></tr><tr><td>S0287149A</td><td>Small Talk</td><td>CustNRIC</td></tr><tr><td>servicing</td><td>Small Talk</td><td>servicing</td></tr><tr><td>H241916306 - client signed and submitted required documents, please check U&I receive?</td><td>Non POS</td><td>AIAPolNum signed submitted required document OpsDpmt receive</td></tr><tr><td>Q512134642 - Power of Attorney (LPA) form 1 done, can the donee can sign on all policy changes from now on?</td><td>POS</td><td>AIAPolNum power attorney lpa form 1 done donee sign policy change</td></tr><tr><td>good afternoon, may i check if i can add in rider for an older term "AIA Secure Term", lets say Critical Illness rider</td><td>POS</td><td>add rider older term secure term let say critical illness rider</td></tr><tr><td>add in rider</td><td>POS</td><td>add rider</td></tr><tr><td>thumbs</td><td>Small Talk</td><td>thumb</td></tr><tr><td>L548630136 - cancel policy with free look</td><td>POS</td><td>AIAPolNum cancel policy free look</td></tr><tr><td>L548630136 - cancel policy</td><td>POS</td><td>AIAPolNum cancel policy</td></tr><tr><td>Q514307943 - Nomination of Beneficiary form 4 submitted in 6 June, please check are you processing the latest copy and is it approve? client asking.</td><td>POS</td><td>AIAPolNum nomination beneficiary form 4 submitted 6 processing latest copy approve asking</td></tr><tr><td>Q514307943</td><td>Small Talk</td><td>AIAPolNum</td></tr><tr><td>L548655577</td><td>Small Talk</td><td>AIAPolNum</td></tr><tr><td>reduction in rider sum assured</td><td>POS</td><td>reduction rider sum assured</td></tr><tr><td>amendment form</td><td>Small Talk</td><td>amendment form</td></tr><tr><td>H231576439 - why policy lasped? client say premium was refunded? please help check</td><td>POS</td><td>AIAPolNum policy lasped say premium refunded</td></tr><tr><td>lam yuk ming - request for wavier of medical for switch of policy</td><td>POS</td><td>lam yuk ming request wavier medical switch policy</td></tr><tr><td>pos</td><td>Small Talk</td><td>OpsDpmt</td></tr><tr><td>Policy</td><td>Small Talk</td><td>policy</td></tr><tr><td>98000078</td><td>Small Talk</td><td>98000078</td></tr><tr><td>Does HSG policy covers long term medication for thyroid removal</td><td>Non POS</td><td>hsg policy cover long term medication thyroid removal</td></tr><tr><td>Can we name beneficiary for C511617982</td><td>POS</td><td>name beneficiary AIAPolNum</td></tr><tr><td>May I eScan the NB pending memo</td><td>Non POS</td><td>escan nb pending memo</td></tr><tr><td>Can you change the rider?</td><td>POS</td><td>change  ...
#
# Policy U126568057
#
# The email ,(image below)
#
# Our FSC email to :
#
# SGNBalex@aia.cm
# No longer in use?
# Even FSC sent,  U&I will not received it right?</td><td>Non POS</td><td>team policy AIAPolNum email image fsc email sgnbalex aia.cm longer use even fsc sent OpsDpmt received right</td></tr><tr><td>Stay Safe</td><td>Small Talk</td><td>stay safe</td></tr><tr><td>claim</td><td>Small Talk</td><td>claim</td></tr><tr><td>Bye Tung Keat</td><td>Small Talk</td><td>tung keat</td></tr><tr><td>major claim link</td><td>Non POS</td><td>major claim link</td></tr><tr><td>Great day</td><td>Small Talk</td><td>day</td></tr><tr><td>Nazmi, appreciate all your kind assistance all the time.</td><td>Small Talk</td><td>nazmi appreciate kind assistance time</td></tr><tr><td>Live chat  L53827705  INSURED ANDRE  PAYOUR  SHAWN Change of Payor Check with Yoga just now May I know  which change of Payour form to use, please  Thanks</td><td>POS</td><td>l53827705 insured andre payour shawn change payor yoga know change payour form use</td></tr><tr><td>Live chat L53827705 INSURED ANDRE PAYOUR SHAWN
# Change of Payor
# Check with Yoga just now
# May I know which change of Payour form to use, please
#
# Thanks</td><td>POS</td><td>l53827705 insured andre payour shawn change payor yoga know change payour form use</td></tr><tr><td>Policy  L53827705  INSURED ANDRE,   PAYOR  SHAWN
# Change of Payor from Father to mother
# Check with Yoga just now
# May I know  which change of Payour form to use, please
#
# Thanks</td><td>POS</td><td>policy l53827705 insured andre payor shawn change payor father mother yoga know change payour form use</td></tr><tr><td>premium statemeent</td><td>POS</td><td>premium statemeent</td></tr><tr><td>L545284815</td><td>Small Talk</td><td>AIAPolNum</td></tr><tr><td>L545284815 premium statement</td><td>POS</td><td>AIAPolNum premium statement</td></tr><tr><td>polciy</td><td>Small Talk</td><td>polciy</td></tr><tr><td>C511534777</td><td>Small Talk</td><td>AIAPolNum</td></tr><tr><td>sole assignment</td><td>POS</td><td>sole assignment</td></tr><tr><td>Stopped</td><td>Small Talk</td><td>stopped</td></tr><tr><td>H240924247</td><td>Small Talk</td><td>AIAPolNum</td></tr><tr><td>Claim decline</td><td>Non POS</td><td>claim decline</td></tr><tr><td>Policy loan</td><td>POS</td><td>policy loan</td></tr><tr><td>policy loan status</td><td>POS</td><td>policy loan status</t

# %%
###################CSV might changed the datatype, tfidf every time different

seed_num = '123'

tfidf = TfidfVectorizer(min_df = 0.002, max_df = 0.9, ngram_range = (1,2), use_idf = True, sublinear_tf = True)
Fit = tfidf.fit(df_stg1_training['qns_clean'])
features_stg1 = tfidf.transform(df_batch_raw.qns_clean).toarray()

pred_stg1 = stg1_model.predict(features_stg1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_batch_raw['department_predict'] = pred_stg1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_batch_raw[['batch_dt','batch_index']] = datetime.now() , df_batch_raw.index
df_batch_raw['batch_key'] = df_batch_raw['batch_dt'].astype(str)+'-'+df_batch_raw['batch_index'].astype(str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify &#39;dtype=object&#39; when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# </div>

# %%
df_batch_stg1_final = df_batch_raw[['batch_key','question','response','confidence','qns_clean','department_predict']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_batch_stg1_final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batch_key</th><th>question</th><th>response</th><th>confidence</th><th>qns_clean</th><th>department_predict</th></tr></thead><tbody><tr><td>2022-09-17 17:32:23.323162-0</td><td>where can i find the medical history form?</td><td>Forms</td><td>0.36</td><td>find medical history form</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-1</td><td>Can I cancel the termination request for L538666424?</td><td>Withdrawal_Submission</td><td>0.51</td><td>cancel termination request AIAPolNum</td><td>POS</td></tr><tr><td>2022-09-17 17:32:23.323162-2</td><td>Policy loan</td><td>Loan_Application</td><td>0.88</td><td>policy loan</td><td>POS</td></tr><tr><td>2022-09-17 17:32:23.323162-3</td><td>questions for policy H235750471 and policy P560526956</td><td>Agency_Policy_Tagging</td><td>0.29</td><td>question policy AIAPolNum policy AIAPolNum</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-4</td><td>ca</td><td>ST_gibberish</td><td>0.59</td><td>ca</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-5</td><td>What is the charges for invest easy using cash</td><td>POS_ILP_Penalty_Charges</td><td>0.50</td><td>charge invest easy using cash</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-6</td><td>H240932750 health shield upgrade</td><td>Changes_to_plan</td><td>0.70</td><td>AIAPolNum health shield upgrade</td><td>POS</td></tr><tr><td>2022-09-17 17:32:23.323162-7</td><td>Check</td><td>POS_Policy_information</td><td>0.41</td><td></td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-8</td><td>Initiate live chat</td><td>Help</td><td>0.57</td><td>initiate</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-9</td><td>witness</td><td>ST_evil</td><td>0.47</td><td>witness</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-10</td><td>Vitality reinstate</td><td>Reinstatement_Procedures_Rules</td><td>0.70</td><td>vitality reinstate</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-11</td><td>kindly advised the reinstatement states for policy U125263191</td><td>Reinstatement_Procedures_Rules</td><td>0.84</td><td>kindly advised reinstatement state policy AIAPolNum</td><td>POS</td></tr><tr><td>2022-09-17 17:32:23.323162-12</td><td>Opai</td><td>ST_questionmark</td><td>0.87</td><td>opai</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-13</td><td>L543681834 Shahrin Bin Abdol final premium, premium notice will be sent to client? change of mode after reinstatement</td><td>HSG_New_Pricing</td><td>0.38</td><td>AIAPolNum shahrin bin abdol final premium premium notice sent change mode reinstatement</td><td>POS</td></tr><tr><td>2022-09-17 17:32:23.323162-14</td><td>claim status for P561195661</td><td>Claims_Status</td><td>0.73</td><td>claim status AIAPolNum</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-15</td><td>i would like to speak to customer service</td><td>Help</td><td>1.00</td><td>speak customer service</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-16</td><td>H239287283 , what is the status of the policy</td><td>Submission_Status</td><td>0.78</td><td>AIAPolNum status policy</td><td>POS</td></tr><tr><td>2022-09-17 17:32:23.323162-17</td><td>Ptosis ( droopy eyelids) surgery claimable under Healthshield</td><td>Claims_Eligibility</td><td>0.99</td><td>ptosis droopy eyelid surgery claimable healthshield</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-18</td><td>Other outstanding matters</td><td>POS_Outstanding_Loan_Amount</td><td>0.28</td><td>outstanding matter</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-19</td><td>requirements for major claims</td><td>Claims_Procedures</td><td>0.63</td><td>requirement major claim</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-20</td><td>uni</td><td>ST_education</td><td>0.32</td><td>uni</td><td>Non POS</td></tr><tr><td>2022-09-17 17:32:23.323162-21</td><td>future premiumdepo ...

# %%
#%sql
#drop table ops_aos_wrk.maia_question_batch_classification;
#create table ops_aos_wrk.maia_question_batch_classification
#(
#batch_key String,
#question String,
#response String,
#confidence Decimal(3,2),
#qns_clean String,
#department_predict String
#)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark_df_stg1 = spark.createDataFrame(df_batch_stg1_final)
spark_df_stg1.write.mode('append').saveAsTable('ops_aos_wrk.maia_question_batch_classification')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Stage 2

# %%
df_watson, df_stg2_raw = spark.sql("""select * from ops_pos_wrk.watson_list""").toPandas(), spark.sql("""select * from ops_aos_wrk.maia_question_batch_classification where department_predict = 'POS' """).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [confidence] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# </div>

# %%
df_watson['Intent_list'] = df_watson['Intent_Conditions'].apply(lambda intent: intent.strip(string.punctuation))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_stg2_watson = df_stg2_raw.merge(df_watson['Intent_list'], how='left', left_on='response',right_on='Intent_list')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_stg2_watson['Intent_in_watson_POS'] = np.where(df_stg2_watson['Intent_list'].isnull(), '0','1')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def stg2_preprocess_1(intent):
  intent_raw = intent.lower()
  intent_punc = " ".join([text.strip(string.punctuation) for text in intent_raw.split('_')])
  intent_punc_sw = " ".join([text for text in nltk.word_tokenize(intent_punc) if text not in stopword_list])
  
  return intent_punc_sw
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def stg2_preprocess_2(question):
  lemmatizer = WordNetLemmatizer()
  pol_format = re.compile(r'\w{1}\d{9}')
  nric_format = re.compile(r'[sfgtm]\d{7}[a-z]')
  emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
  
  qns_raw = question.lower()
  qns_pol = pol_format.sub(r'', qns_raw)
  qns_pol_nric = nric_format.sub(r'', qns_pol)
  qns_pol_nric_emoji = emoji_pattern.sub(r'', qns_pol_nric)
  qns_pol_nric_emoji_punc = " ".join([text.strip(string.punctuation) for text in qns_pol_nric_emoji.split(' ')])
  qns_pol_nric_emoji_punc_sw = " ".join([text for text in nltk.word_tokenize(qns_pol_nric_emoji_punc) if text not in stopword_list])
  qns_pol_nric_emoji_punc_sw_lm = ' '.join([lemmatizer.lemmatize(text) for text in nltk.word_tokenize(qns_pol_nric_emoji_punc_sw)])
  
  return qns_pol_nric_emoji_punc_sw_lm
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_stg2_watson['response_c'] = df_stg2_watson['response'].apply(stg2_preprocess_1)
df_stg2_watson['qns_c'] = df_stg2_watson['question'].apply(stg2_preprocess_2)
df_stg2_watson['response_qns_c_combine'] = df_stg2_watson.apply(lambda df: df['response_c'] + ' ' + df['qns_c'], axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## load stg2 training set
df_stg2_training = pd.read_pickle(file_path+"stg2_clean.pkl")
display(df_stg2_training)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>response</th><th>question</th><th>confidence</th><th>tag</th><th>Department</th><th>is_pos_content</th><th>response_c</th><th>question_c</th><th>Ratio</th><th>Ratio_combine</th><th>response_question</th><th>row_similarities</th></tr></thead><tbody><tr><td>Refund</td><td>Q514050177 dividend payment</td><td>0.32420958280563356</td><td>No</td><td>POS</td><td>1</td><td>refund</td><td>dividend payment</td><td>0.27</td><td>0.08753658735752107</td><td>refund dividend payment</td><td>0.0</td></tr><tr><td>Coupon_Payment_Details</td><td>L533278532 coupon</td><td>0.7661356449127197</td><td>Yes</td><td>POS</td><td>1</td><td>coupon payment details</td><td>coupon</td><td>0.43</td><td>0.32943832731246947</td><td>coupon payment details coupon</td><td>0.5957817822877031</td></tr><tr><td>Withdrawal_Procedures</td><td>Q514050177 dividend withdrawal</td><td>0.9163254261016847</td><td>Yes</td><td>POS</td><td>1</td><td>withdrawal procedures</td><td>dividend withdrawal</td><td>0.5</td><td>0.45816271305084233</td><td>withdrawal procedures dividend withdrawal</td><td>0.44429209974432626</td></tr><tr><td>Premium_Holiday</td><td>premium holiday</td><td>0.9836024284362794</td><td>Yes</td><td>POS</td><td>1</td><td>premium holiday</td><td>premium holiday</td><td>1.0</td><td>0.9836024284362794</td><td>premium holiday premium holiday</td><td>1.0</td></tr><tr><td>Reinstatement_Procedures_Rules</td><td>H235938743 reinstatement</td><td>0.5169537782669067</td><td>Yes</td><td>POS</td><td>1</td><td>reinstatement procedures rules</td><td>reinstatement</td><td>0.6</td><td>0.310172266960144</td><td>reinstatement procedures rules reinstatement</td><td>0.5433500159506385</td></tr><tr><td>NB_Instant_COL</td><td>H224151117 - client signed and sent in a counteroffer, why counter offer closed?</td><td>0.6671443939208985</td><td>No</td><td>POS</td><td>0</td><td>nb instant col</td><td>- client signed and sent in a counteroffer , why counter offer closed ?</td><td>0.21</td><td>0.14010032272338868</td><td>nb instant col - client signed and sent in a counteroffer , why counter offer closed ?</td><td>0.0</td></tr><tr><td>POS_LPA_POA</td><td>Q512134642 - Power of Attorney (LPA) form 1 done, can the donee can sign on all policy changes from now on?</td><td>0.9699352741241456</td><td>Yes</td><td>POS</td><td>1</td><td>pos lpa poa</td><td>- power of attorney ( lpa ) form 1 done , can the donee can sign on all policy change from now on ?</td><td>0.18</td><td>0.1745883493423462</td><td>pos lpa poa - power of attorney ( lpa ) form 1 done , can the donee can sign on all policy change from now on ?</td><td>0.24773678864776605</td></tr><tr><td>Marketing_SFT</td><td>good afternoon, may i check if i can add in rider for an older term "AIA Secure Term", lets say Critical Illness rider</td><td>0.7572103023529053</td><td>No</td><td>POS</td><td>0</td><td>marketing sft</td><td>good afternoon , may i check if i can add in rider for an older term `` aia secure term '' , let say critical illness rider</td><td>0.12</td><td>0.09086523628234863</td><td>marketing sft good afternoon , may i check if i can add in rider for an older term `` aia secure term '' , let say critical illness rider</td><td>0.0</td></tr><tr><td>Add_Rider</td><td>add in rider</td><td>0.8875681400299074</td><td>Yes</td><td>POS</td><td>1</td><td>add rider</td><td>add in rider</td><td>0.86</td><td>0.7633086004257204</td><td>add rider add in rider</td><td>0.8311766594166912</td></tr><tr><td>Freelook</td><td>L548630136 - cancel policy with free look</td><td>0.7700406074523927</td><td>Yes</td><td>POS</td><td>1</td><td>freelook</td><td>- cancel policy with free look</td><td>0.42</td><td>0.3234170551300049</td><td>freelook - cancel policy with free look</td><td>0.0</td></tr><tr><td>Withdrawal_Procedures</td><td>L548630136 - cancel policy</td><td>0.6362829685211182</td><td>Yes</td><td>POS</td><td>1</td><td>withdrawal proced ...

# %%
tfidf = TfidfVectorizer(ngram_range = (1,1))
tfidf.fit(df_stg2_training['response_question'])
tfidf_qns = tfidf.transform(df_stg2_watson['qns_c']).todense()
tfidf_response = tfidf.transform(df_stg2_watson['response_c']).todense()

row_similarities = [1-spatial.distance.cosine(tfidf_qns[x],tfidf_response[x]) for x in range(len(tfidf_qns))]

df_stg2_watson['row_similarities'] = row_similarities
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.8/site-packages/scipy/spatial/distance.py:728: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# </div>

# %%
df_stg2_watson['ratio'] =  df_stg2_watson.apply(lambda x: Decimal(fuzz.ratio(x['qns_c'],x['response_c'])*0.01), axis = 1)
df_stg2_watson['ratio_combine'] = df_stg2_watson['ratio']*df_stg2_watson['confidence']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_stg2_batch = df_stg2_watson[['ratio', 'ratio_combine', 'confidence', 'Intent_in_watson_POS', 'row_similarities']]

for i in df_stg2_batch.columns:
  df_stg2_batch[i] = df_stg2_batch[i].apply(lambda x : float(x))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-2829380880215015&gt;:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stg2_batch[i] = df_stg2_batch[i].apply(lambda x : float(x))
# </div>

# %%
df_stg2_watson['MAIA_Answer_Correct'] = stg2_model.predict(df_stg2_batch)
df_stg2_upload = df_stg2_watson[['batch_key','question','response','MAIA_Answer_Correct']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#%sql

#create table ops_aos_wrk.maia_question_batch_answer_examination
#(
#batch_key String,
#question String,
#response String,
#MAIA_Answer_Correct String
#)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
spark_df_stg2_upload = spark.createDataFrame(df_stg2_upload)
spark_df_stg2_upload.write.mode('append').saveAsTable('ops_aos_wrk.maia_question_batch_answer_examination')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
